# %%
text_file_name = "test.txt"
output_file_name = "words.txt"
noun_count = 50

# %%
import re
from collections import Counter
from konlpy.tag import Komoran, Twitter, Kkma, Mecab, Hannanum

def get_tags(text, ntags=50):
    spliter = Komoran()
    nouns = spliter.nouns(text)
    count = Counter(nouns)
    return_list = []
    for n, c in count.most_common(ntags):
        temp = {'tag': n, 'count': c}
        return_list.append(temp)
    return return_list

# %%
open_text_file = open(text_file_name, 'r')
text = open_text_file.read()

emoji_pattern = re.compile("["
        u"\U0001F600-\U0001F64F"  # emoticons
        u"\U0001F300-\U0001F5FF"  # symbols & pictographs
        u"\U0001F680-\U0001F6FF"  # transport & map symbols
        u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
        u"\U00002728"u"\❤️"u"\✔"u"\uf33f"'.''•' '🤹‍♂''!''?'              
                           "]+", flags=re.UNICODE)
text = emoji_pattern.sub('', text)
text = re.sub('\n', ' ', text)
print(text)
# for line in lines:
#     line = emoji_pattern.sub(r'', line)
#     print(line)

# tags = get_tags(text, noun_count)
# open_text_file.close()
# open_output_file = open(output_file_name, 'w')
# for tag in tags:
#     noun = tag['tag']
#     count = tag['count']
#     open_output_file.write('{} {}\n'.format(noun, count))
# open_output_file.close()
# Out:
# 바지가 끌려 --*-- The mood is so interesting now, some mysterious    #mood #mysterious #look #crazygirl #happyme #seoul #koreamodel #ukrainemodel #night #walk #model #me #nastyven --*-- 何気に車好き カロスキルに行った時 フェラーリくんいた〜 隣にはランボルギーニくんもいた〜 #フェラーリ #車好き #페라리  #굿모닝그램 --*-- 오랜만에 #진대감 #차돌삼합 #맛집 --*-- 고작 두달 쉬었다고 피부 너 이러기있음  #닥터크리미신사 --*-- 지치는 퇴근길 #오늘나말리지마 #다먹을거야 #날놔버림 #사진찍을힘은있음 --*-- with #music  #cloudnine #sinsastation #beautifulseoul --*-- Chillin like a villain @nikkiiquintero  --*-- 내 동생은 네이비 성애자인 날 위해  10만원 어치를 사고 내게 파우치를 건네줬다  #고마워 #동생 #네이비 #블루 #성애자 #사랑해 #오오티디 #daily #lfl #l4l #좋아요 --*-- 서울당구학교 ^ㅇ^ --*-- Korean food daebak miss it --*-- 여자끼리 힐링 - - - - - - - - #도미인호텔 #야식스타그램 #일본라멘 #힐링중 #사우나#엄마랑동생이랑 #신사 #off#먹스타그램 --*-- 오늘 저녁은 BLT 샌드위치~ 다들 맛저하세용~ #blt샌드위치 #이제이스모자이크까페 --*-- 다시 놀러 가고 싶어용 #신사 #가로수길 #라인프렌즈샵   #고딩 #고1 #01 #17 #방학하루전 #여고생 #거울샷 #전신샷 #살빼자 #일상 #daily #셀피 #selca #selfie #학교 #데일리룩 #dailylook #비욘드클로젯 #조끼 #놀고싶다 --*--       #selfietime #decor #vintage #girl #beautiful #instagood #interiors #lightblue #pink #korea #pastel  #韓国 #可愛い #ピンク #美人 #青空 #ソウル #愛 #일상 #핑크 #파스텔 #셀스타그램 #카페 #셀카 #얼스타그램 #데일리룩 #sinsa #신사 #ootd #룩북 --*-- #普通的上班族 #新沙站 #屋顶 #looftop #goodmorning #신사역의아침 #오늘도 --*-- #새벽감성 #성시경 #두사람 들으면 떠오르는 나으 #예비신부 #보고싶다  --*-- My eyes turn bright green when I'm happy     #happyme #green #eyes #smile #people #seoul #crazylife #korea #banillamodels #ukrainemodel #photo #selfie #reallife #life #look #mood #model #me #nastyven --*--  #닭한마리 #닭 #치킨 #칼국수사리 #먹스타그램 #푸드스타그램 #보글보글 #지글지글 #치느님 #데일리 #instadaily #yummy #foodie #foodstagram #foodporn #beerstagram #sojushots #rainyday #술스타그램 #압구정맛집 #강남맛집 #chicken #chickensoup #chickenstew --*-- Nice to see you Sukses Geom-Gaek nya Mas --*-- 요즘 밥을 혼자서 잘 사먹는 나를 볼때마다-- 삶의 배고품을 알게되었다--우선 먹고 화이팅-- 집에가자마자 자기--#혼밥 #신사역 #쌀국수 #ㅠㅠ #피곤하다 --*--  #신사 #가부커피 꽁커피가역시제일꿀맛~ --*-- #급벙개 #이모임은사랑입니다 #행복하자 #아프지말고 #고마운분들 오늘도 한경아점장님은 적당히 취하셨습니다♡ 오늘도 김자영팀장님은 저를 강하게 키워주셨습니다♡ --*-- #오디션 #대기 #신사 숙녀여러분 --*-- 오늘 점심은 #크로핀 에 #아아  #쁠로13 담엔 #크로아상먹어야지 #이힛 --*-- 귀엽다고              #model #photo #셀 #flowerstagram #좋아요 #lookbook #퇴근 #새벽 #촬영 #블랙 #화이트 #데일리그램 #스튜디오 #flowers #꽃 #selfie #instagood #일상 #선팔하면맞팔 #선팔 #소통해요 #일상스타그램 #단발 #졸작 #like4like #daily#dailylook #촬영 #셀스타그램 #양말 --*-- 이쁜 쓰레기           #model #photo #셀 #flowerstagram #좋아요 #lookbook #퇴근 #새벽 #촬영 #블랙 #화이트 #데일리그램 #스튜디오 #flowers #리그램 #selfie #instagood #일상 #선팔하면맞팔 #선팔 #소통해요 #일상스타그램 #단발 #졸작 #like4like #daily#dailylook #촬영 #셀스타그램 #꽃 --*--            #model #photo #셀 #flowerstagram #좋아요 #lookbook #퇴근 #새벽 #촬영 #블랙 #화이트 #데일리그램 #스튜디오 #flowers #리그램 #selfie #instagood #일상 #선팔하면맞팔 #선팔 #소통해요 #일상스타그램 #단발 #졸작 #like4like #daily#dailylook #촬영 #셀스타그램 #대학교 --*--  방금 알았는데 남성렬 쉐프가 나랑 동갑이었따 한참 형인줄 알았는데ㅋㅋ 정말 잘 먹었습니다 어쨌든 좋아해요 많이 - He is a very powerful and delicate chef - #foodpics #food #foodporn #foodstagram #foodgasm #foodie #instafood #hungry #delicious #yummy #diet #asianfood #powerful #chef #professionalchef #GATI #fusionfood #selfie #handsome #great #happy #가티 #가로수길 #남성렬셰프 #올리브쇼 #냉장고를부탁해 #쉐프 #인간미 #동갑 #충격 --*-- #latepost D-21 @wantonmeiz and i both love seafood so we thought why not 砸钱  #간장게장 never again  · · #먹스타그램#맛스타그램#일상#인스타#데일리 --*-- 출퇴근 2시간씩걸리면 무슨느낌인줄알아요  --*-- 혜련언니 미리 생일축하했던날 가로수길 간다고 다들 잔뜩 들뜬 우리들 귀여운 언니들 때문에 요새 많이많이 웃는다  #selfie #goodtime #happybirthday #instafriend #라뷰 --*-- Smiling, you give people a piece of your energy, so smile more often and people will be energetic ☝ * * * #smile #happy #folks #crazylife #people #energylife #crazyqueen #girl #model #korea #ukrainemodel #seoul #day #catgirl #me #nastyven --*-- #도미 동네 꼬마들 사이에 둘러싸여 #인디언밥 중 #인기쟁이 --*-- 비안와서 좋아~~🤘                   #insta #instagram #instadaily #instaselfie #selca #instaphoto #instapic #instalike #dailylook #ootd #selstagram #like4like #daily #selfie #l4l#f4f #일상#데일리 #카페스타그램 #우중충☁ #셀피#셀카 #얼스타 #셀스타#신사#강남 #카페 --*-- 말차 크로핀 --*-- import 대두단백질 from '콩국수'; // import 만두 from '서비스'; // --*-- - 2달째 수강중인 학생분 작품 고생했어요 글고 너무 이뻐요 @si0___ - 온라인 몰 런칭 후 오히려 수강문의가 더 많이 들어옵니다만 아직 가르치고 있으시냐고 질문이 젤 많아요 ㅎㅎ 현재 수업 활기차게 진행중이니 편안히 상담하셔요 ㅎㅎㅎ - 다만 언제까지 수강을 진행하게 ...

# %%
tag = Hannanum()
tag.pos(text)
# Out:
# [('바지', 'N'),
#  ('가', 'J'),
#  ('끌리', 'P'),
#  ('어', 'E'),
#  ('--*--', 'S'),
#  ('The', 'F'),
#  ('mood', 'F'),
#  ('is', 'F'),
#  ('so', 'F'),
#  ('interesting', 'F'),
#  ('now', 'F'),
#  (',', 'S'),
#  ('some', 'F'),
#  ('mysterious', 'F'),
#  ('#mood', 'N'),
#  ('#mysterious', 'N'),
#  ('#look', 'N'),
#  ('#crazygirl', 'N'),
#  ('#happyme', 'N'),
#  ('#seoul', 'N'),
#  ('#koreamodel', 'N'),
#  ('#ukrainemodel', 'N'),
#  ('#night', 'N'),
#  ('#walk', 'N'),
#  ('#model', 'N'),
#  ('#me', 'N'),
#  ('#nastyven', 'N'),
#  ('--*--', 'S'),
#  ('何気に車好き', 'N'),
#  ('カロスキルに行った時', 'N'),
#  ('フェラーリくんいた〜', 'N'),
#  ('隣にはランボルギーニくんもいた〜', 'N'),
#  ('#フェラーリ', 'N'),
#  ('#車好き', 'N'),
#  ('#페라리', 'N'),
#  ('#굿모닝그램', 'N'),
#  ('--*--', 'S'),
#  ('오랜만', 'N'),
#  ('에', 'J'),
#  ('#진대감', 'N'),
#  ('#차돌삼합', 'N'),
#  ('#맛집', 'N'),
#  ('--*--', 'S'),
#  ('고작', 'M'),
#  ('두달', 'N'),
#  ('쉬', 'P'),
#  ('었다', 'E'),
#  ('고', 'J'),
#  ('피부', 'N'),
#  ('너', 'N'),
#  ('이러기있음', 'N'),
#  ('#닥터크리미신사', 'N'),
#  ('--*--', 'S'),
#  ('지치', 'P'),
#  ('는', 'E'),
#  ('퇴근길', 'N'),
#  ('#오늘나말리지마', 'N'),
#  ('#다먹을거야', 'N'),
#  ('#날놔버림', 'N'),
#  ('#사진찍을힘은있음', 'N'),
#  ('--*--', 'S'),
#  ('with', 'F'),
#  ('#music', 'N'),
#  ('#cloudnine', 'N'),
#  ('#sinsastation', 'N'),
#  ('#beautifulseoul', 'N'),
#  ('--*--', 'S'),
#  ('Chillin', 'F'),
#  ('like', 'F'),
#  ('a', 'F'),
#  ('villain', 'F'),
#  ('@', 'S'),
#  ('nikkiiquintero', 'F'),
#  ('--*--', 'S'),
#  ('내', 'N'),
#  ('동생', 'N'),
#  ('은', 'J'),
#  ('네이비', 'N'),
#  ('성애자인', 'N'),
#  ('날', 'N'),
#  ('위하', 'P'),
#  ('어', 'E'),
#  ('10만원', 'N'),
#  ('어치', 'N'),
#  ('를', 'J'),
#  ('사', 'P'),
#  ('고', 'E'),
#  ('내', 'P'),
#  ('게', 'E'),
#  ('파우치', 'N'),
#  ('를', 'J'),
#  ('건네', 'P'),
#  ('어', 'E'),
#  ('주', 'P'),
#  ('었다', 'E'),
#  ('#고마워', 'N'),
#  ('#동생', 'N'),
#  ('#네이비', 'N'),
#  ('#블루', 'N'),
#  ('#성애', 'N'),
#  ('이', 'J'),
#  ('자', 'E'),
#  ('#사랑해', 'N'),
#  ('#오오티디', 'N'),
#  ('#daily', 'N'),
#  ('#lfl', 'N'),
#  ('#l4l', 'N'),
#  ('#좋아요', 'N'),
#  ('--*--', 'S'),
#  ('서울당구학교', 'N'),
#  ('^ㅇ^', 'N'),
#  ('--*--', 'S'),
#  ('Korean', 'F'),
#  ('food', 'F'),
#  ('daebak', 'F'),
#  ('miss', 'F'),
#  ('it', 'F'),
#  ('--*--', 'S'),
#  ('여자', 'N'),
#  ('끼리', 'J'),
#  ('힐링', 'N'),
#  ('-', 'S'),
#  ('-', 'S'),
#  ('-', 'S'),
#  ('-', 'S'),
#  ('-', 'S'),
#  ('-', 'S'),
#  ('-', 'S'),
#  ('-', 'S'),
#  ('#도미인호텔', 'N'),
#  ('#야식스타그램', 'N'),
#  ('#일본라멘', 'N'),
#  ('#힐링중', 'N'),
#  ('#사우나#엄마랑동생이랑', 'N'),
#  ('#신사', 'N'),
#  ('#off#먹스타그램', 'N'),
#  ('--*--', 'S'),
#  ('오늘', 'N'),
#  ('저녁', 'N'),
#  ('은', 'J'),
#  ('BLT', 'F'),
#  ('샌드위치', 'N'),
#  ('~', 'S'),
#  ('다들', 'N'),
#  ('맛저하세용~', 'N'),
#  ('#blt샌드위치', 'N'),
#  ('#이제이스모자이크까페', 'N'),
#  ('--*--', 'S'),
#  ('다시', 'M'),
#  ('놀', 'P'),
#  ('러', 'E'),
#  ('가', 'P'),
#  ('고', 'E'),
#  ('싶어용', 'N'),
#  ('#신사', 'N'),
#  ('#가로수길', 'N'),
#  ('#라인프렌즈샵', 'N'),
#  ('#고딩', 'N'),
#  ('#고1', 'N'),
#  ('#01', 'N'),
#  ('#17', 'N'),
#  ('#방학하루전', 'N'),
#  ('#여고생', 'N'),
#  ('#거울샷', 'N'),
#  ('#전신샷', 'N'),
#  ('#살빼', 'N'),
#  ('이', 'J'),
#  ('자', 'E'),
#  ('#일상', 'N'),
#  ('#daily', 'N'),
#  ('#셀피', 'N'),
#  ('#selca', 'N'),
#  ('#selfie', 'N'),
#  ('#학교', 'N'),
#  ('#데일리룩', 'N'),
#  ('#dailylook', 'N'),
#  ('#비욘드클로젯', 'N'),
#  ('#조끼', 'N'),
#  ('#놀고싶다', 'N'),
#  ('--*--', 'S'),
#  ('#selfietime', 'N'),
#  ('#decor', 'N'),
#  ('#vintage', 'N'),
#  ('#girl', 'N'),
#  ('#beautiful', 'N'),
#  ('#instagood', 'N'),
#  ('#interiors', 'N'),
#  ('#lightblue', 'N'),
#  ('#pink', 'N'),
#  ('#korea', 'N'),
#  ('#pastel\xa0', 'N'),
#  ('#韓国', 'N'),
#  ('#可愛い', 'N'),
#  ('#ピンク', 'N'),
#  ('#美人', 'N'),
#  ('#青空', 'N'),
#  ('#ソウル', 'N'),
#  ('#愛', 'N'),
#  ('#일상', 'N'),
#  ('#핑크', 'N'),
#  ('#파스텔', 'N'),
#  ('#셀스타그램', 'N'),
#  ('#카페', 'N'),
#  ('#셀카', 'N'),
#  ('#얼스타그램', 'N'),
#  ('#데일리룩', 'N'),
#  ('#sinsa', 'N'),
#  ('#신사\xa0#ootd', 'N'),
#  ('#룩북', 'N'),
#  ('--*--', 'S'),
#  ('#普通的上班族', 'N'),
#  ('#新沙站', 'N'),
#  ('#屋顶', 'N'),
#  ('#looftop', 'N'),
#  ('#goodmorning', 'N'),
#  ('#신사역의아침', 'N'),
#  ('#오늘', 'N'),
#  ('도', 'J'),
#  ('--*--', 'S'),
#  ('#새벽감성', 'N'),
#  ('#성시경', 'N'),
#  ('#두사람', 'N'),
#  ('들', 'P'),
#  ('면', 'E'),
#  ('떠오르', 'P'),
#  ('는', 'E'),
#  ('나으', 'N'),
#  ('#예비신부', 'N'),
#  ('#보고싶다', 'N'),
#  ('--*--', 'S'),
#  ('My', 'F'),
#  ('eyes', 'F'),
#  ('turn', 'F'),
#  ('bright', 'F'),
#  ('green', 'F'),
#  ('when', 'F'),
#  ('I', 'F'),
#  ("'", 'S'),
#  ('m', 'F'),
#  ('happy', 'F'),
#  ('#happyme', 'N'),
#  ('#green', 'N'),
#  ('#eyes', 'N'),
#  ('#smile', 'N'),
#  ('#people', 'N'),
#  ('#seoul', 'N'),
#  ('#crazylife', 'N'),
#  ('#korea', 'N'),
#  ('#banillamodels', 'N'),
#  ('#ukrainemodel', 'N'),
#  ('#photo', 'N'),
#  ('#selfie', 'N'),
#  ('#reallife', 'N'),
#  ('#life', 'N'),
#  ('#look', 'N'),
#  ('#mood', 'N'),
#  ('#model', 'N'),
#  ('#me', 'N'),
#  ('#nastyven', 'N'),
#  ('--*--', 'S'),
#  ('#닭한마리', 'N'),
#  ('#닭', 'N'),
#  ('#치킨', 'N'),
#  ('#칼국수사리', 'N'),
#  ('#먹스타그램', 'N'),
#  ('#푸드스타그램', 'N'),
#  ('#보글보글', 'N'),
#  ('#지글지글', 'N'),
#  ('#치느님', 'N'),
#  ('#데일리', 'N'),
#  ('#instadaily', 'N'),
#  ('#yummy', 'N'),
#  ('#foodie', 'N'),
#  ('#foodstagram', 'N'),
#  ('#foodporn', 'N'),
#  ('#beerstagram', 'N'),
#  ('#sojushots', 'N'),
#  ('#rainyday', 'N'),
#  ('#술스타그램', 'N'),
#  ('#압구정맛집', 'N'),
#  ('#강남맛집', 'N'),
#  ('#chicken', 'N'),
#  ('#chickensoup', 'N'),
#  ('#chickenstew', 'N'),
#  ('--*--', 'S'),
#  ('Nice', 'F'),
#  ('to', 'F'),
#  ('see', 'F'),
#  ('you', 'F'),
#  ('Sukses', 'F'),
#  ('Geom', 'F'),
#  ('-', 'S'),
#  ('Gaek', 'F'),
#  ('nya', 'F'),
#  ('Mas', 'F'),
#  ('--*--', 'S'),
#  ('요즘', 'M'),
#  ('밥', 'N'),
#  ('을', 'J'),
#  ('혼자', 'N'),
#  ('서', 'J'),
#  ('잘', 'M'),
#  ('사먹', 'N'),
#  ('는', 'J'),
#  ('나', 'N'),
#  ('를', 'J'),
#  ('보', 'P'),
#  ('ㄹ', 'E'),
#  ('때', 'N'),
#  ('마다', 'J'),
#  ('--', 'S'),
#  ('삶', 'N'),
#  ('의', 'J'),
#  ('배고품', 'N'),
#  ('을', 'J'),
#  ('알', 'P'),
#  ('게', 'E'),
#  ('되', 'P'),
#  ('었다', 'E'),
#  ('--', 'S'),
#  ('우선', 'N'),
#  ('먹', 'P'),
#  ('고', 'E'),
#  ('화이팅--', 'N'),
#  ('집에가자마', 'N'),
#  ('이', 'J'),
#  ('자', 'E'),
#  ('자기--#혼밥', 'N'),
#  ('#신사역', 'N'),
#  ('#쌀국수', 'N'),
#  ('#ㅠㅠ', 'N'),
#  ('#피곤하', 'N'),
#  ('이', 'J'),
#  ('다', 'E'),
#  ('--*--', 'S'),
#  ('#신사', 'N'),
#  ('#가부커피', 'N'),
#  ('꽁커피가역시제일꿀맛~', 'N'),
#  ('--*--', 'S'),
#  ('#급벙개', 'N'),
#  ('#이모임은사랑입니다', 'N'),
#  ('#행복하', 'N'),
#  ('이', 'J'),
#  ('자', 'E'),
#  ('#아프지말고', 'N'),
#  ('#고마운분들', 'N'),
#  ('오늘', 'N'),
#  ('도', 'J'),
#  ('한경아점장님', 'N'),
#  ('은', 'J'),
#  ('적당히', 'M'),
#  ('취하셨습니다♡', 'N'),
#  ('오늘', 'N'),
#  ('도', 'J'),
#  ('김자영팀장님', 'N'),
#  ('은', 'J'),
#  ('저', 'N'),
#  ('를', 'J'),
#  ('강하', 'P'),
#  ('게', 'E'),
#  ('키워주셨습니다♡', 'N'),
#  ('--*--', 'S'),
#  ('#오디션', 'N'),
#  ('#대', 'N'),
#  ('이', 'J'),
#  ('기', 'E'),
#  ('#신사', 'N'),
#  ('숙녀여러분', 'N'),
#  ('--*--', 'S'),
#  ('오늘', 'N'),
#  ('점심', 'N'),
#  ('은', 'J'),
#  ('#크로핀', 'N'),
#  ('에', 'P'),
#  ('어', 'E'),
#  ('#아아', 'N'),
#  ('#쁠로13', 'N'),
#  ('달', 'P'),
#  ('ㅁ', 'E'),
#  ('엔', 'J'),
#  ('#크로아상먹어야지', 'N'),
#  ('#이힛', 'N'),
#  ('--*--', 'S'),
#  ('귀엽', 'P'),
#  ('다', 'E'),
#  ('고', 'J'),
#  ('#model', 'N'),
#  ('#photo', 'N'),
#  ('#셀', 'N'),
#  ('#flowerstagram', 'N'),
#  ('#좋아요', 'N'),
#  ('#lookbook', 'N'),
#  ('#퇴근', 'N'),
#  ('#새벽', 'N'),
#  ('#촬영', 'N'),
#  ('#블랙', 'N'),
#  ('#화이트', 'N'),
#  ('#데일리그램', 'N'),
#  ('#스튜디오', 'N'),
#  ('#flowers', 'N'),
#  ('#꽃', 'N'),
#  ('#selfie', 'N'),
#  ('#instagood', 'N'),
#  ('#일상', 'N'),
#  ('#선팔하면맞팔', 'N'),
#  ('#선팔', 'N'),
#  ('#소통해요', 'N'),
#  ('#일상스타그램', 'N'),
#  ('#단발', 'N'),
#  ('#졸작', 'N'),
#  ('#like4like', 'N'),
#  ('#daily#dailylook', 'N'),
#  ('#촬영', 'N'),
#  ('#셀스타그램', 'N'),
#  ('#양말', 'N'),
#  ('--*--', 'S'),
#  ('이쁘', 'P'),
#  ('ㄴ', 'E'),
#  ('쓰레기', 'N'),
#  ('#model', 'N'),
#  ('#photo', 'N'),
#  ('#셀', 'N'),
#  ('#flowerstagram', 'N'),
#  ('#좋아요', 'N'),
#  ('#lookbook', 'N'),
#  ('#퇴근', 'N'),
#  ('#새벽', 'N'),
#  ('#촬영', 'N'),
#  ('#블랙', 'N'),
#  ('#화이트', 'N'),
#  ('#데일리그램', 'N'),
#  ('#스튜디오', 'N'),
#  ('#flowers', 'N'),
#  ('#리그램', 'N'),
#  ('#selfie', 'N'),
#  ('#instagood', 'N'),
#  ('#일상', 'N'),
#  ('#선팔하면맞팔', 'N'),
#  ('#선팔', 'N'),
#  ('#소통해요', 'N'),
#  ('#일상스타그램', 'N'),
#  ('#단발', 'N'),
#  ('#졸작', 'N'),
#  ('#like4like', 'N'),
#  ('#daily#dailylook', 'N'),
#  ('#촬영', 'N'),
#  ('#셀스타그램', 'N'),
#  ('#꽃', 'N'),
#  ('--*--', 'S'),
#  ('#model', 'N'),
#  ('#photo', 'N'),
#  ('#셀', 'N'),
#  ('#flowerstagram', 'N'),
#  ('#좋아요', 'N'),
#  ('#lookbook', 'N'),
#  ('#퇴근', 'N'),
#  ('#새벽', 'N'),
#  ('#촬영', 'N'),
#  ('#블랙', 'N'),
#  ('#화이트', 'N'),
#  ('#데일리그램', 'N'),
#  ('#스튜디오', 'N'),
#  ('#flowers', 'N'),
#  ('#리그램', 'N'),
#  ('#selfie', 'N'),
#  ('#instagood', 'N'),
#  ('#일상', 'N'),
#  ('#선팔하면맞팔', 'N'),
#  ('#선팔', 'N'),
#  ('#소통해요', 'N'),
#  ('#일상스타그램', 'N'),
#  ('#단발', 'N'),
#  ('#졸작', 'N'),
#  ('#like4like', 'N'),
#  ('#daily#dailylook', 'N'),
#  ('#촬영', 'N'),
#  ('#셀스타그램', 'N'),
#  ('#대학교', 'N'),
#  ('--*--', 'S'),
#  ('방금', 'M'),
#  ('알', 'P'),
#  ('아ㄴ데', 'E'),
#  ('남성렬', 'N'),
#  ('쉐프', 'N'),
#  ('가', 'J'),
#  ('나', 'N'),
#  ('랑', 'J'),
#  ('동갑이었따', 'N'),
#  ('한참', 'M'),
#  ('형', 'N'),
#  ('이', 'J'),
#  ('ㄴ', 'E'),
#  ('줄', 'N'),
#  ('알았는뎈ㅋ', 'N'),
#  ('정말', 'M'),
#  ('잘', 'M'),
#  ('먹', 'P'),
#  ('었습니다', 'E'),
#  ('어쨌든', 'M'),
#  ('좋', 'P'),
#  ('아', 'E'),
#  ('하', 'P'),
#  ('어', 'E'),
#  ('요', 'J'),
#  ('많', 'P'),
#  ('이', 'X'),
#  ('-', 'S'),
#  ('He', 'F'),
#  ('is', 'F'),
#  ('a', 'F'),
#  ('very', 'F'),
#  ('powerful', 'F'),
#  ('and', 'F'),
#  ('delicate', 'F'),
#  ('chef', 'F'),
#  ('-', 'S'),
#  ('#foodpics', 'N'),
#  ('#food', 'N'),
#  ('#foodporn', 'N'),
#  ('#foodstagram', 'N'),
#  ('#foodgasm', 'N'),
#  ('#foodie', 'N'),
#  ('#instafood', 'N'),
#  ('#hungry', 'N'),
#  ('#delicious', 'N'),
#  ('#yummy', 'N'),
#  ('#diet', 'N'),
#  ('#asianfood', 'N'),
#  ('#powerful', 'N'),
#  ('#chef', 'N'),
#  ('#professionalchef', 'N'),
#  ('#GATI', 'N'),
#  ('#fusionfood', 'N'),
#  ('#selfie', 'N'),
#  ('#handsome', 'N'),
#  ('#great', 'N'),
#  ('#happy', 'N'),
#  ('#가티', 'N'),
#  ('#가로수길', 'N'),
#  ('#남성렬셰프', 'N'),
#  ('#올리브쇼', 'N'),
#  ('#냉장고를부탁해', 'N'),
#  ('#쉐프', 'N'),
#  ('#인간미', 'N'),
#  ('#동갑', 'N'),
#  ('#충격', 'N'),
#  ('--*--', 'S'),
#  ('#latepost', 'N'),
#  ('D', 'F'),
#  ('-', 'S'),
#  ('21', 'N'),
#  ('@', 'S'),
#  ('wantonmeiz', 'F'),
#  ('and', 'F'),
#  ('i', 'F'),
#  ('both', 'F'),
#  ('love', 'F'),
#  ('seafood', 'F'),
#  ('so', 'F'),
#  ('we', 'F'),
#  ('thought', 'F'),
#  ('why', 'F'),
#  ('not', 'F'),
#  ('砸钱', 'N'),
#  ('#간장게장', 'N'),
#  ('never', 'F'),
#  ('again', 'F'),
#  ('·', 'S'),
#  ('·', 'S'),
#  ('#먹스타그램#맛스타그램#일상#인스타#데일리', 'N'),
#  ('--*--', 'S'),
#  ('출퇴근', 'N'),
#  ('2시간씩걸리', 'N'),
#  ('이', 'J'),
#  ('면', 'E'),
#  ('무슨느낌인줄알아요', 'N'),
#  ('--*--', 'S'),
#  ('혜련언니', 'N'),
#  ('미리', 'M'),
#  ('생일축하했던날', 'N'),
#  ('가로수길', 'N'),
#  ('가', 'P'),
#  ('ㄴ다', 'E'),
#  ('고', 'J'),
#  ('다들', 'N'),
#  ('잔뜩', 'M'),
#  ('들뜨', 'P'),
#  ('ㄴ', 'E'),
#  ('우리들', 'N'),
#  ('귀엽', 'P'),
#  ('은', 'E'),
#  ('언니들', 'N'),
#  ('때문', 'N'),
#  ('에', 'J'),
#  ('요새', 'M'),
#  ('많이많이', 'M'),
#  ('웃', 'P'),
#  ('는다', 'E'),
#  ('#selfie', 'N'),
#  ('#goodtime', 'N'),
#  ('#happybirthday', 'N'),
#  ('#instafriend', 'N'),
#  ('#라뷰', 'N'),
#  ('--*--', 'S'),
#  ('Smiling', 'F'),
#  (',', 'S'),
#  ('you', 'F'),
#  ('give', 'F'),
#  ('people', 'F'),
#  ('a', 'F'),
#  ('piece', 'F'),
#  ('of', 'F'),
#  ('your', 'F'),
#  ('energy', 'F'),
#  (',', 'S'),
#  ('so', 'F'),
#  ('smile', 'F'),
#  ('more', 'F'),
#  ('often', 'F'),
#  ('and', 'F'),
#  ('people', 'F'),
#  ('will', 'F'),
#  ('be', 'F'),
#  ('energetic', 'F'),
#  ('☝', 'N'),
#  ('*', 'S'),
#  ('*', 'S'),
#  ('*', 'S'),
#  ('#smile', 'N'),
#  ('#happy', 'N'),
#  ('#folks', 'N'),
#  ('#crazylife', 'N'),
#  ('#people', 'N'),
#  ('#energylife', 'N'),
#  ('#crazyqueen', 'N'),
#  ('#girl', 'N'),
#  ('#model', 'N'),
#  ('#korea', 'N'),
#  ('#ukrainemodel', 'N'),
#  ('#seoul', 'N'),
#  ('#day', 'N'),
#  ('#catgirl', 'N'),
#  ('#me', 'N'),
#  ('#nastyven', 'N'),
#  ('--*--', 'S'),
#  ('#도미', 'N'),
#  ('동네', 'N'),
#  ('꼬마들', 'N'),
#  ('사이', 'N'),
#  ('에', 'J'),
#  ('둘러싸이', 'P'),
#  ('어', 'E'),
#  ('#인디언밥', 'N'),
#  ('중', 'N'),
#  ('#인기쟁', 'N'),
#  ('이', 'J'),
#  ('--*--', 'S'),
#  ('비안와서', 'N'),
#  ('좋아~~落', 'N'),
#  ('#insta', 'N'),
#  ('#instagram', 'N'),
#  ('#instadaily', 'N'),
#  ('#instaselfie', 'N'),
#  ('#selca', 'N'),
#  ('#instaphoto', 'N'),
#  ('#instapic', 'N'),
#  ('#instalike', 'N'),
#  ('#dailylook', 'N'),
#  ('#ootd', 'N'),
#  ('#selstagram', 'N'),
#  ('#like4like', 'N'),
#  ('#daily', 'N'),
#  ('#selfie', 'N'),
#  ('#l4l#f4f', 'N'),
#  ('#일상#데일리', 'N'),
#  ('#카페스타그램', 'N'),
#  ('#우중충☁', 'N'),
#  ('#셀피#셀카', 'N'),
#  ('#얼스타', 'N'),
#  ('#셀스타#신사#강남', 'N'),
#  ('#카페', 'N'),
#  ('--*--', 'S'),
#  ('말', 'P'),
#  ('ㄹ', 'E'),
#  ('차', 'N'),
#  ('크로핀', 'N'),
#  ('--*--', 'S'),
#  ('import', 'F'),
#  ('대두단백질', 'N'),
#  ('from', 'F'),
#  ("'콩국수';", 'N'),
#  ('//', 'S'),
#  ('import', 'F'),
#  ('만두', 'N'),
#  ('from', 'F'),
#  ("'", 'S'),
#  ('서비스', 'N'),
#  ("';", 'S'),
#  ('//', 'S'),
#  ('--*--', 'S'),
#  ('-', 'S'),
#  ('2달', 'N'),
#  ('째', 'X'),
#  ('수강', 'N'),
#  ('중', 'X'),
#  ('이', 'J'),
#  ('ㄴ', 'E'),
#  ('학생분', 'N'),
#  ('작품', 'N'),
#  ('고생', 'N'),
#  ('하', 'X'),
#  ('었어', 'E'),
#  ('요', 'J'),
#  ('글', 'N'),
#  ('고', 'J'),
#  ('너무', 'M'),
#  ('이쁘', 'P'),
#  ('어', 'E'),
#  ('요', 'J'),
#  ('@si0___', 'N'),
#  ('-', 'S'),
#  ('온라인', 'N'),
#  ('몰', 'P'),
#  ('ㄹ', 'E'),
#  ('런칭', 'N'),
#  ('후', 'N'),
#  ('오히려', 'M'),
#  ('수강문의', 'N'),
#  ('가', 'J'),
#  ('더', 'M'),
#  ('많', 'P'),
#  ('이', 'X'),
#  ('들어옵니다', 'N'),
#  ('만', 'J'),
#  ('아직', 'M'),
#  ('가르치', 'P'),
#  ('고', 'E'),
#  ('있', 'P'),
#  ('으시냐', 'E'),
#  ('고', 'J'),
#  ('질문', 'N'),
#  ('이', 'J'),
#  ('젤', 'N'),
#  ('많', 'P'),
#  ('아', 'E'),
#  ('요', 'J'),
#  ('ㅎㅎ', 'N'),
#  ('현재', 'N'),
#  ('수업', 'N'),
#  ('활기차', 'P'),
#  ('게', 'E'),
#  ('진행', 'N'),
#  ('중', 'X'),
#  ('이', 'J'),
#  ('니', 'E'),
#  ('편안히', 'M'),
#  ('상담', 'N'),
#  ('하', 'X'),
#  ('시어', 'E'),
#  ('요', 'J'),
#  ('ㅎㅎㅎ', 'N'),
#  ('-', 'S'),
#  ('다만', 'M'),
#  ('언제', 'N'),
#  ('까지', 'J'),
#  ('수강', 'N'),
#  ('을', 'J'),
#  ('진행', 'N'),
#  ('하', 'X'),
#  ('게', 'E'),
#  ('되', 'P'),
#  ('ㄹ지', 'E'),
#  ('는', 'J'),
#  ('저', 'N'),
#  ('도', 'J'),
#  ('모르', 'P'),
#  ('겠습니다', 'E'),
#  ('-', 'S'),
#  ("'", 'S'),
#  ('배우', 'P'),
#  ('ㄹ', 'E'),
#  ('수', 'N'),
#  ('있', 'P'),
#  ('을', 'E'),
#  ('때', 'N'),
#  ('배우', 'P'),
#  ('시는', 'E'),
#  ('것', 'N'),
#  ('도', 'J'),
#  ('기회', 'N'),
#  ('라는', 'J'),
#  ('선물', 'N'),
#  ('이', 'J'),
#  ('ㅂ니다', 'E'),
#  ("'", 'S')]
